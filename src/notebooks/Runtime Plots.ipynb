# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.DataFrame({'Cores':[1,2,4,8,16,32,  1,2,4,8,16,32,  1,2,4,8,16,32,  1,2,4,8,16,32,  1,2,4,8,16,32,  
                            1,2,4,8,16,32,  1,2,4,8,16,32,  1,2,4,8,16,32,  1,2,4,8,16,32,  1,2,4,8,16,32], \
                   
                  'VaiPhy_CSMC':[np.nan,np.nan,16456,10464,7379,np.nan,  np.nan,np.nan,16504,9522,7398,np.nan,  
                                 np.nan,np.nan,16456,9041,7976,np.nan,  np.nan,np.nan,16501,9884,7405,np.nan,  
                                 np.nan,np.nan,15473,9124,7473,np.nan,  np.nan,np.nan,15441,10572,7404,np.nan,  
                                 np.nan,np.nan,15575,9586,7416,np.nan,  np.nan,np.nan,15577,9404,7401,np.nan,  
                                 np.nan,np.nan,15304,9405,7582,np.nan,  np.nan,np.nan,15140,8599,7607,np.nan],\
                   
                  'VBPI-NF':[112354,130181,107635,120713,127095,np.nan,  127270,129878,119018,111496,102512,np.nan,  
                             121265,129164,113091,94245,96368,np.nan,  132661,128603,111905,94128,111970,np.nan,  
                             133142,130372,112756,89848,113203,np.nan,  133209,127659,111945,89204,100054,np.nan,  
                             130888,128943,112731,130922,111646,np.nan,  131173,127973,121368,119394,102751,np.nan,  
                             131793,127663,120190,120882,100635,np.nan,  131461,125421,118890,125675,102210,np.nan]})
df = df[['Cores','VaiPhy_CSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy_CSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 4))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,135000])
plt.legend(loc="upper right", bbox_to_anchor=(1.34, 1.02))
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

matplotlib.rcParams.update({'font.size': 20})
df = pd.DataFrame({'Cores':[1,2,4,8,16,  1,2,4,8,16,  1,2,4,8,16,  1,2,4,8,16,  1,2,4,8,16,  
                            1,2,4,8,16,  1,2,4,8,16,  1,2,4,8,16,  1,2,4,8,16,  1,2,4,8,16], \
                   
                   'VaiPhy':[4894,3885,3911,4485,3551,  4891,3884,3831,3557,3585,  
                             4941,3928,3748,4140,4056,  4970,3888,3840,4128,3561,  
                             4963,3861,3817,3479,3623,  4909,4588,3701,4946,3562,  
                             4894,4476,3739,3908,3601,  4934,4311,3848,3713,3560,  
                             4894,4876,3512,3744,3726,  4121,4929,3495,3591,3656],\
                   
                  'φ-CSMC':[np.nan,24337,16456,10464,7379,  np.nan,24448,16504,9522,7398,  
                                 np.nan,24358,16456,9041,7976,  np.nan,24577,16501,9884,7405,  
                                 np.nan,25565,15473,9124,7473,  np.nan,25970,15441,10572,7404,  
                                 np.nan,25819,15575,9586,7416,  np.nan,25883,15577,9404,7401,  
                                 np.nan,26227,15304,9405,7582,  np.nan,26252,15140,8599,7607],\
                   
                  'VBPI-NF':[112354,130181,107635,120713,127095,  127270,129878,119018,111496,102512,  
                             121265,129164,113091,94245,96368,  132661,128603,111905,94128,111970,  
                             133142,130372,112756,89848,113203,  133209,127659,111945,89204,100054,  
                             130888,128943,112731,130922,111646,  131173,127973,121368,119394,102751,  
                             131793,127663,120190,120882,100635,  131461,125421,118890,125675,102210]})
df = df[['Cores','VaiPhy','φ-CSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,135000])
plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.6))
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime.eps', format='eps', bbox_inches='tight')

df = df[['Cores','VaiPhy','φ-CSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,30000])
#plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.5))
plt.legend('',frameon=False)
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime_zoomed.eps', format='eps', bbox_inches='tight')

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

matplotlib.rcParams.update({'font.size': 20})
df = pd.DataFrame({'Cores':[2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  
                            2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16], \
                   
                   'VaiPhy':[3885,3911,4485,3551,  3884,3831,3557,3585,  
                             3928,3748,4140,4056,  3888,3840,4128,3561,  
                             3861,3817,3479,3623,  4588,3701,4946,3562,  
                             4476,3739,3908,3601,  4311,3848,3713,3560,  
                             4876,3512,3744,3726,  4929,3495,3591,3656],\
                   
                  'φ-CSMC':[24337,16456,10464,7379,  24448,16504,9522,7398,  
                            24358,16456,9041,7976,  24577,16501,9884,7405,  
                            25565,15473,9124,7473,  25970,15441,10572,7404,  
                            25819,15575,9586,7416,  25883,15577,9404,7401,  
                            26227,15304,9405,7582,  26252,15140,8599,7607],\
                   
                  'VBPI-NF':[130181,107635,120713,127095,  129878,119018,111496,102512,  
                             129164,113091,94245,96368,  128603,111905,94128,111970,  
                             130372,112756,89848,113203,  127659,111945,89204,100054,  
                             128943,112731,130922,111646,  127973,121368,119394,102751,  
                             127663,120190,120882,100635,  125421,118890,125675,102210]})
df = df[['Cores','VaiPhy','φ-CSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,135000])
plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.6))
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime.eps', format='eps', bbox_inches='tight')

df = df[['Cores','VaiPhy','φ-CSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,30000])
#plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.5))
plt.legend('',frameon=False)
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime_zoomed.eps', format='eps', bbox_inches='tight')

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

matplotlib.rcParams.update({'font.size': 20})
df = pd.DataFrame({'Cores':[2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  
                            2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16], \
                   
                   'VaiPhy':[3885,3911,4485,3551,  3884,3831,3557,3585,  
                             3928,3748,4140,4056,  3888,3840,4128,3561,  
                             3861,3817,3479,3623,  4588,3701,4946,3562,  
                             4476,3739,3908,3601,  4311,3848,3713,3560,  
                             4876,3512,3744,3726,  4929,3495,3591,3656],\
                   
                  'φ-CSMC':[24337,16456,10464,7379,  24448,16504,9522,7398,  
                            24358,16456,9041,7976,  24577,16501,9884,7405,  
                            25565,15473,9124,7473,  25970,15441,10572,7404,  
                            25819,15575,9586,7416,  25883,15577,9404,7401,  
                            26227,15304,9405,7582,  26252,15140,8599,7607],\
                   
                   'VCSMC':[np.nan,np.nan,np.nan,6848,  np.nan,np.nan,np.nan,6826, 
                           np.nan,np.nan,np.nan,6852,   np.nan,np.nan,np.nan,np.nan,
                           np.nan,np.nan,np.nan,np.nan, np.nan,np.nan,np.nan,np.nan,
                           np.nan,np.nan,np.nan,np.nan, np.nan,np.nan,np.nan,np.nan, 
                           np.nan,np.nan,np.nan,np.nan, np.nan,np.nan,np.nan,np.nan],\
                   
                  'VBPI-NF':[130181,107635,120713,127095,  129878,119018,111496,102512,  
                             129164,113091,94245,96368,  128603,111905,94128,111970,  
                             130372,112756,89848,113203,  127659,111945,89204,100054,  
                             128943,112731,130922,111646,  127973,121368,119394,102751,  
                             127663,120190,120882,100635,  125421,118890,125675,102210]})
df = df[['Cores','VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,135000])
plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.6))
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime.eps', format='eps', bbox_inches='tight')

df = df[['Cores','VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,30000])
#plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.5))
plt.legend('',frameon=False)
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime_zoomed.eps', format='eps', bbox_inches='tight')

# %%
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

matplotlib.rcParams.update({'font.size': 20})
df = pd.DataFrame({'Cores':[2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  
                            2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16,  2,4,8,16], \
                   
                   'VaiPhy':[3885,3911,4485,3551,  3884,3831,3557,3585,  
                             3928,3748,4140,4056,  3888,3840,4128,3561,  
                             3861,3817,3479,3623,  4588,3701,4946,3562,  
                             4476,3739,3908,3601,  4311,3848,3713,3560,  
                             4876,3512,3744,3726,  4929,3495,3591,3656],\
                   
                  'φ-CSMC':[24337,16456,10464,7379,  24448,16504,9522,7398,  
                            24358,16456,9041,7976,  24577,16501,9884,7405,  
                            25565,15473,9124,7473,  25970,15441,10572,7404,  
                            25819,15575,9586,7416,  25883,15577,9404,7401,  
                            26227,15304,9405,7582,  26252,15140,8599,7607],\
                   
                   'VCSMC':[np.nan,np.nan,np.nan,6848,  np.nan,np.nan,np.nan,6826, 
                           np.nan,np.nan,np.nan,6852,   np.nan,np.nan,np.nan,np.nan,
                           np.nan,np.nan,np.nan,np.nan, np.nan,np.nan,np.nan,np.nan,
                           np.nan,np.nan,np.nan,np.nan, np.nan,np.nan,np.nan,np.nan, 
                           np.nan,np.nan,np.nan,np.nan, np.nan,np.nan,np.nan,np.nan],\
                   
                  'VBPI-NF':[130181,107635,120713,127095,  129878,119018,111496,102512,  
                             129164,113091,94245,96368,  128603,111905,94128,111970,  
                             130372,112756,89848,113203,  127659,111945,89204,100054,  
                             128943,112731,130922,111646,  127973,121368,119394,102751,  
                             127663,120190,120882,100635,  125421,118890,125675,102210]})
df = df[['Cores','VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,135000])
plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.6))
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime.eps', format='eps', bbox_inches='tight')

df = df[['Cores','VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF']]
dd=pd.melt(df,id_vars=['Cores'],value_vars=['VaiPhy','φ-CSMC', 'VCSMC','VBPI-NF'],var_name='Methods')
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cores',y='value',data=dd,hue='Methods')
plt.ylim([0,30000])
#plt.legend(loc="upper right", bbox_to_anchor=(1.0, 0.5))
plt.legend('',frameon=False)
plt.xlabel("Number of cores")
plt.ylabel("Wall-clock time (sec)")
plt.savefig('runtime_zoomed.eps', format='eps', bbox_inches='tight')
